# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("../data/raw/sales.csv")

# %%
df.head()
# Out:
#     Order ID  Order Date Customer ID    Customer Name      Segment   Region  \
# 0  ORD-00657  2022-01-04   CUST-1050      Eric Carney    Corporate    North
# 1  ORD-01016  2022-01-04   CUST-1271  Jasmin Alvarado     Consumer    North
# 2  ORD-01855  2022-01-04   CUST-1072   Whitney Peters    Corporate     East
# 3  ORD-00598  2022-01-05   CUST-1219    Justin Torres    Corporate    North
# 4  ORD-01268  2022-01-05   CUST-1193  Debra Christian  Home Office  Central
#
#           Category Sub-Category            Product Name      Sales  Quantity  \
# 0  Office Supplies    Envelopes        Padded Envelopes    4062.02        11
# 1        Furniture    Bookcases         Corner Bookcase    4504.88         5
# 2  Office Supplies    Envelopes  Mailing Envelopes Pack     417.51         5
# 3       Technology      Copiers   Office Copier Machine  156211.14         5
# 4        Furniture       Chairs         Mesh Task Chair   11240.01         3
#
#    Discount    Profit
# 0       0.0   1061.06
# ...
